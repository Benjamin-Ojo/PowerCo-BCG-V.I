# %% [markdown]
# <a href="https://colab.research.google.com/github/ojoadekunle/PowerCo-BCG-V.I/blob/main/PowerCo_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis
# ---
# Importing python packages.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Show Plot in jupyter Note
# %matplotlib inline 

# Setting colour style
sns.set(color_codes=True)
sns.set_style('whitegrid')

# %% [markdown]
# ## Loading Data
# ---

# %% [markdown]
# For this project we will be using the following data set:
#
# 1.  client_data
# 2.  Price_data

# %%
# client data
client_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PowerCo_Project/client_data.csv')

client_df
# Out:
#                                      id  ... churn
# 0      24011ae4ebbe3035111d65fa7c15bc57  ...     1
# 1      d29c2c54acc38ff3c0614d0a653813dd  ...     0
# 2      764c75f661154dac3a6c254cd082ea7d  ...     0
# 3      bba03439a292a1e166f80264c16191cb  ...     0
# 4      149d57cf92fc41cf94415803a877cb4b  ...     0
# ...                                 ...  ...   ...
# 14601  18463073fb097fc0ac5d3e040f356987  ...     0
# 14602  d0a6f71671571ed83b2645d23af6de00  ...     1
# 14603  10e6828ddd62cbcf687cb74928c4c2d2  ...     1
# 14604  1cf20fd6206d7678d5bcafd28c53b4db  ...     0
# 14605  563dde550fd624d7352f3de77c0cdfcd  ...     0
#
# [14606 rows x 26 columns]

# %%
# Pricing data 
price_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PowerCo_Project/price_data.csv')

price_df.head()
# Out:
#                                  id  ... price_mid_peak_fix
# 0  038af19179925da21a25619c5a24b745  ...                0.0
# 1  038af19179925da21a25619c5a24b745  ...                0.0
# 2  038af19179925da21a25619c5a24b745  ...                0.0
# 3  038af19179925da21a25619c5a24b745  ...                0.0
# 4  038af19179925da21a25619c5a24b745  ...                0.0
#
# [5 rows x 8 columns]

# %%
# Number of unique values in Client dataset 

client_df.nunique()
# Out:
# id                                14606
# channel_sales                         8
# cons_12m                          11065
# cons_gas_12m                       2112
# cons_last_month                    4751
# date_activ                         1796
# date_end                            368
# date_modif_prod                    2129
# date_renewal                        386
# forecast_cons_12m                 13993
# forecast_cons_year                 4218
# forecast_discount_energy             12
# forecast_meter_rent_12m            3528
# forecast_price_energy_off_peak      516
# forecast_price_energy_peak          329
# forecast_price_pow_off_peak          41
# has_gas                               2
# imp_cons                           7752
# margin_gross_pow_ele               2391
# margin_net_pow_ele                 2391
# nb_prod_act                          10
# net_margin                        11965
# num_years_antig                      13
# ...

# %%
# Number of unique values in Price dataset

price_df.nunique()
# Out:
# id                    16096
# price_date               12
# price_off_peak_var     1853
# price_peak_var         1189
# price_mid_peak_var      711
# price_off_peak_fix       66
# price_peak_fix           31
# price_mid_peak_fix       28
# dtype: int64

# %% [markdown]
# ## Descriptive statistics of data
# ---

# %%
# client Data Shape
print(f"The client dataset has {client_df.shape[0]} rows and {client_df.shape[1]} colunms")

print(client_df.shape)
# Out:
# The client dataset has 14606 rows and 26 colunms
# (14606, 26)

# %%
# client Descriptive Statistics 
client_df.info()

print('\n\nMissing Values\n================================================================')

client_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
# Price Descriptive Statistics
price_df.info()

print('\n\nMissing Values\n================================================================')

price_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB
#
#
# Missing Values
# ...
# id                    0
# price_date            0
# price_off_peak_var    0
# price_peak_var        0
# price_mid_peak_var    0
# price_off_peak_fix    0
# price_peak_fix        0
# price_mid_peak_fix    0
# dtype: int64

# %% [markdown]
# ## Statistical Summary
# ---

# %%
# Client Statistics Summary
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  ...       pow_max         churn
# count  1.460600e+04  1.460600e+04  ...  14606.000000  14606.000000
# mean   1.592203e+05  2.809238e+04  ...     18.135136      0.097152
# std    5.734653e+05  1.629731e+05  ...     13.534743      0.296175
# min    0.000000e+00  0.000000e+00  ...      3.300000      0.000000
# 25%    5.674750e+03  0.000000e+00  ...     12.500000      0.000000
# 50%    1.411550e+04  0.000000e+00  ...     13.856000      0.000000
# 75%    4.076375e+04  0.000000e+00  ...     19.172500      0.000000
# max    6.207104e+06  4.154590e+06  ...    320.000000      1.000000
#
# [8 rows x 18 columns]

# %%
#Price Statistics Summary
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  ...  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000  ...   193002.000000       193002.000000
# mean             0.141027        0.054630  ...       10.622875            6.409984
# std              0.025032        0.049924  ...       12.841895            7.773592
# min              0.000000        0.000000  ...        0.000000            0.000000
# 25%              0.125976        0.000000  ...        0.000000            0.000000
# 50%              0.146033        0.085483  ...        0.000000            0.000000
# 75%              0.151635        0.101673  ...       24.339581           16.226389
# max              0.280700        0.229788  ...       36.490692           17.458221
#
# [8 rows x 6 columns]

# %% [markdown]
# ### Relational Analysis and Data Visualization
#
# In this sub-section we will be looking the relationship that each variable such as consumption, tenurship, etc. have with churning rate and with the aid of visualiszation tools we can better understand the relationship that each variables have with the churning rate of of our customer. Below are function that can help you with data visualization.

# %%
# Corelation Analysis

corelation = client_df[['cons_12m', 'cons_gas_12m', 'cons_last_month', 'forecast_cons_12m', 'forecast_discount_energy', 'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'churn']].corr()

sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %% [markdown]
# There seems to be a stronge negative relationship between churn and consumtion of customer by -0.046 for eletricity consumption and - 0.038 for gas, meaning that an increase of 1% will decrease churn rate for eletricity by 4.6 % and for gas by 3.8. Althought this is an important finding, the level of significant is low and more analysis is needed.

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100

# %%
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %% [markdown]
# There is approximatly 10% of our client customers are churn and 90% active.

# %%
# Chacking the relationship between demand for our client service and rate 
# of churn of customers

que_churn = sns.catplot(x= 'churn', y= 'cons_12m', hue='has_gas', data=client_df, height=10)

# %%
# Chacking the relaiontion the exist between categorical variables and churn

# relationship between tenure of our client and the rate of churn. 

sns.catplot(x='num_years_antig', hue='churn', kind='count', data=client_df, height=10, estimator=np.count_nonzero)

# %% [markdown]
# From this bar chart above we can observe that there seems to be a relationship between the number of years a customer have spent with our client and the rate of churn. In the first two year there seems to be no churn amoung our client customer but as we enter the third year there was a sparp increase in the rate of churn and this increase contiune to the fourth year and gradualy decreasing when as our client customer enter the fiveth year.

# %%
# Relationship between the channel of sales and the churn rate of customers
# and I will also be checking the relationship that exist between customers
# that has both gas and eletricity, customers that doesn't.

cs_churn = sns.catplot(y='channel_sales', hue='churn', col= 'has_gas', kind='count', data=client_df, height=10)

# %% [markdown]
# The graph above shows us that there is a relationship between the channel of sale a customer is useing, whether the customer also uses gas, and the churn rate. This observation shows us that depending on the channel of sales a customer is more or less likely to churn.

# %%
# Relationship between the origin_up and churn rate

orup_churn = sns.catplot(y='origin_up', hue='churn', kind='count', data=client_df, height=10)

# %%
# Checking the Normalized Distribution 

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Active": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Active","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %%
fig, axs = plt.subplots(nrows=4, figsize=(18, 25))

plot_distribution(client_df, 'cons_12m', axs[0])
plot_distribution(client_df[client_df['has_gas'] == 't'], 'cons_gas_12m', axs[1])
plot_distribution(client_df, 'cons_last_month', axs[2])
plot_distribution(client_df, 'imp_cons', axs[3])

# %% [markdown]
# From the histograms above, we can observe that the customer data is positivly stewed and it seems it is mostly stewed at the top and botton of which is mostly caused by outliers. In other to check for the present of outliers, we will be plotting a box plot, this will show us the present of outliers in the each features.

# %%
fig, axs = plt.subplots(nrows=4, figsize=(18,25))

sns.boxplot(data=client_df, x='cons_12m', ax = axs[0])
sns.boxplot(data=client_df[client_df['has_gas'] == 't'], x='cons_gas_12m', ax=axs[1])
sns.boxplot(data=client_df, x="cons_last_month", ax=axs[2])
sns.boxplot(data=client_df, x="imp_cons", ax=axs[3])


# Remove scientific notation
for ax in axs:
    ax.ticklabel_format(style='plain', axis='x')
    # Set x-axis limit
    axs[0].set_xlim(-200000, 2000000)
    axs[1].set_xlim(-200000, 2000000)
    axs[2].set_xlim(-20000, 100000)
    plt.show()

# %% [markdown]
# This is shows us that there is a stronge present of outliers in the dataset, this will affect our model performance. The next phase of this project will handle this problem of outliers.

# %%
fig, axs = plt.subplots(nrows=7, figsize=(18, 25))

plot_distribution(client_df, 'forecast_cons_12m', axs[0])
plot_distribution(client_df, 'forecast_cons_year', axs[1])
plot_distribution(client_df, 'forecast_discount_energy', axs[2])
plot_distribution(client_df, 'forecast_meter_rent_12m', axs[3])
plot_distribution(client_df, 'forecast_price_energy_off_peak', axs[4])
plot_distribution(client_df, 'forecast_price_energy_peak', axs[5])
plot_distribution(client_df, 'forecast_price_pow_off_peak', axs[6])

# %% [markdown]
# We can observe that our data are mostly positivly skewed and this can be seen from the distribution of our data, and high values with long tail in our graphs.

# %% [markdown]
# ## Price Sencitivity Hypothesis Testing
# ---
#
# In this section we will be defining what price sencitivity, how we are mearsuring it with our dataset, and explaining how changes in price of our services can affect the churning rate of our client.

# %% [markdown]
# ### What is Price Sensitivity?
#
# Price sensitivity can be define as the degree of responses of a feature to a change in the price.
#
# In testing our client hypothesis on whether churn has a significant relationship with change in price, we will be deriving the correlation between price and churn over time.

# %% [markdown]
# ### Measuring rice Sensitivity to Churn Rate.
#
# To measure the price sensitivity of our data we will be measuring correlative relationship that exist between churn and price. Base off the result we get from this measurement we will be able to determine whether there exist a negative or positive relationship between churn and price. If the relationship between the churn and price is positive, we will not reject the null hypothesis stating that there exist a relationship between churn and price. Other wise, we will accept the Alternative Hypothesis that there exist no relatonship between churn and price. The following steps will be taken to clean, sort, and measure our data in other to test our client hypothesis:
#
#
#
# *   STEP 1: Convert the `price_date` column into date_time formate. This is will make it easy to sort and manupulate our data according to the date of each customer.
#
# *   STEP 2: Get the average price for a year, half the year, and three month( a quarter of a year).
#
# *   STEP 3: Change the names of all columns in the price dataset to reflect the new dataset, after this we will add the price dataset `price_off_peak_ver` with `price_off_peak_fix` and do the same for the ramaining 4 columns.
#
# *   STEP 4: Marge the a`client_churn` and `new_price`dataset into one dataframe using the `i.d` as the primary key.
#
# *   STEP 5: Perform a correlation on the new marge data to measure the relationship between churn and price. Following this we will create a heat map to visualize this relationship.
#
# *   STEP 6: Marge the `price_analysis` dataset with the `client_df` and dropping the churn column.

# %%
"""
STEP 1: CONVERTING THE STRICK DATASET TO A DATE_TIME FORMATE.
"""
client_df['date_activ'] = pd.to_datetime(client_df['date_activ'])
client_df['date_end'] = pd.to_datetime(client_df['date_end'])
client_df['date_modif_prod'] = pd.to_datetime(client_df['date_modif_prod'])
client_df['date_renewal'] = pd.to_datetime(client_df['date_renewal'])
price_df['price_date'] = pd.to_datetime(price_df['price_date'])

client_df.info()
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  datetime64[ns]
#  6   date_end                        14606 non-null  datetime64[ns]
#  7   date_modif_prod                 14606 non-null  datetime64[ns]
#  8   date_renewal                    14606 non-null  datetime64[ns]
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
# ...

# %%
"""
STEP 2: GETTING AVERAGES PRICE FOR EACH MONTH.
"""
# Calculating the Average Price for the Verious Time Span. 
average_year_price = price_df.groupby('id').mean().reset_index()
average_6m_price = price_df[price_df['price_date'] >= '2015-07-01'].groupby('id').mean().reset_index()
average_3m_price = price_df[price_df['price_date'] >= '2015-10-01'].groupby('id').mean().reset_index()

average_year_price
# Out:
#                                      id  ...  price_mid_peak_fix
# 0      0002203ffbb812588b632b9e628cc38d  ...           16.280694
# 1      0004351ebdd665e6ee664792efc4fd13  ...            0.000000
# 2      0010bcc39e42b3c2131ed2ce55246e3c  ...            0.000000
# 3      0010ee3855fdea87602a5b7aba8e42de  ...           16.258971
# 4      00114d74e963e47177db89bc70108537  ...            0.000000
# ...                                 ...  ...                 ...
# 16091  ffef185810e44254c3a4c6395e6b4d8a  ...           16.507972
# 16092  fffac626da707b1b5ab11e8431a4d0a2  ...            0.000000
# 16093  fffc0cacd305dd51f316424bbb08d1bd  ...           16.763569
# 16094  fffe4f5646aa39c7f97f95ae2679ce64  ...           16.242678
# 16095  ffff7fa066f1fb305ae285bb03bf325a  ...           16.258971
#
# [16096 rows x 7 columns]

# %%
"""
STEP 3: CHANGING COLUMNS NAME AND ADDING COLUMNS WITH SIMILAR DATA.
"""

# Changing Columns Names.
average_year_price = average_year_price.rename(
                                              index=str,
                                               columns= {'price_off_peak_var': 'ave_year_price_offpeak_var', 
                                                'price_peak_var': 'ave_year_price_peak_var',
                                                'price_mid_peak_var': 'ave_year_price_midpeak_var',
                                                'price_off_peak_fix': 'ave_year_price_offpeak_fix',
                                                'price_peak_fix': 'ave_year_price_peak_fix',
                                                'price_mid_peak_fix': 'ave_year_price_midpeak_fix'
                                                })
average_year_price['ave_year_price_offpeak'] = average_year_price['ave_year_price_offpeak_var'] + average_year_price['ave_year_price_offpeak_fix']
average_year_price['ave_year_price_peak'] = average_year_price['ave_year_price_peak_var'] + average_year_price['ave_year_price_peak_fix']
average_year_price['ave_year_price_midpeak'] = average_year_price['ave_year_price_midpeak_var'] + average_year_price['ave_year_price_midpeak_fix']

average_6m_price = average_6m_price.rename(index=str,
                                           columns={'price_off_peak_var': 'ave_6m_price_offpeak_var', 
                                                'price_peak_var': 'ave_6m_price_peak_var',
                                                'price_mid_peak_var': 'ave_6m_price_midpeak_var',
                                                'price_off_peak_fix': 'ave_6m_price_offpeak_fix',
                                                'price_peak_fix': 'ave_6m_price_peak_fix',
                                                'price_mid_peak_fix': 'ave_6m_price_midpeak_fix',
                                                })

average_6m_price['ave_6m_price_offpeak'] = average_6m_price['ave_6m_price_offpeak_var'] + average_6m_price['ave_6m_price_offpeak_fix']
average_6m_price['ave_6m_price_peak'] = average_6m_price['ave_6m_price_peak_var'] + average_6m_price['ave_6m_price_peak_fix']
average_6m_price['ave_6m_price_midpeak'] = average_6m_price['ave_6m_price_midpeak_var'] + average_6m_price['ave_6m_price_midpeak_fix']

average_3m_price = average_3m_price.rename(index= str,
                                           columns={'price_off_peak_var': 'ave_3m_price_offpeak_var', 
                                                'price_peak_var': 'ave_3m_price_peak_var',
                                                'price_mid_peak_var': 'ave_3m_price_midpeak_var',
                                                'price_off_peak_fix': 'ave_3m_price_offpeak_fix',
                                                'price_peak_fix': 'ave_3m_price_peak_fix',
                                                'price_mid_peak_fix': 'ave_3m_price_midpeak_fix',
                                                })
average_3m_price['ave_3m_price_offpeak'] = average_3m_price['ave_3m_price_offpeak_var'] + average_3m_price['ave_3m_price_offpeak_fix']
average_3m_price['ave_3m_price_peak'] = average_3m_price['ave_3m_price_peak_var'] + average_3m_price['ave_3m_price_peak_fix']
average_3m_price['ave_3m_price_midpeak'] = average_3m_price['ave_3m_price_midpeak_var'] + average_3m_price['ave_3m_price_midpeak_fix']

# %%
"""
STEP 3: MARGING THE CLIENT CHURN WITH THE PRICE DATASET. 
"""
new_price = pd.merge(average_year_price, average_6m_price, on='id')
new_price = new_price.merge(average_3m_price,how='inner', on='id')
price_analysis = pd.merge(new_price , client_df[['id','churn']], how='inner', on='id')

price_analysis
# Out:
#                                      id  ...  churn
# 0      0002203ffbb812588b632b9e628cc38d  ...      0
# 1      0004351ebdd665e6ee664792efc4fd13  ...      0
# 2      0010bcc39e42b3c2131ed2ce55246e3c  ...      0
# 3      00114d74e963e47177db89bc70108537  ...      0
# 4      0013f326a839a2f6ad87a1859952d227  ...      0
# ...                                 ...  ...    ...
# 14601  ffebf6a979dd0b17a41076df1057e733  ...      0
# 14602  fffac626da707b1b5ab11e8431a4d0a2  ...      0
# 14603  fffc0cacd305dd51f316424bbb08d1bd  ...      0
# 14604  fffe4f5646aa39c7f97f95ae2679ce64  ...      0
# 14605  ffff7fa066f1fb305ae285bb03bf325a  ...      0
#
# [14606 rows x 29 columns]

# %%
"""
STEP 4: CALCULATING THE AVERAGE PRICE
"""

# Churn average price 
churn_price['av_price'] = churn_price.mean(axis=1)

churn_price
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                           id  ...   av_price
# price_date                                    ...
# 2015-01-01  7363a2ebfbb3148c8ef6d25323e4093a  ...  11.776864
# 2015-02-01  7363a2ebfbb3148c8ef6d25323e4093a  ...  11.776864
# 2015-03-01  7363a2ebfbb3148c8ef6d25323e4093a  ...  11.776864
# ...

# %%
# active customer average price

active_price['av_price'] = active_price.mean(axis=1)

active_price
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                           id  ...   av_price
# price_date                                    ...
# 2015-01-01  038af19179925da21a25619c5a24b745  ...   6.345471
# ...

# %%
# The Next step is to get the average price for each month of both churn
# and active customer 

# Churn Customer

churn_monthly_price = pd.DataFrame(churn_price[ 'av_price'])
churn_monthly_price = churn_monthly_price.groupby(by='price_date').mean()
churn_monthly_price
# Out:
#             av_price
# price_date
# 2015-01-01  8.971752
# 2015-02-01  8.965148
# 2015-03-01  8.973038
# 2015-04-01  8.962775
# 2015-05-01  8.955254
# 2015-06-01  8.893899
# 2015-07-01  8.973113
# 2015-08-01  8.989957
# 2015-09-01  8.968106
# 2015-10-01  8.954626
# 2015-11-01  8.963204
# 2015-12-01  8.991372

# %%
# Active Customers
active_monthly_price = pd.DataFrame(active_price[ 'av_price'])
active_monthly_price = active_monthly_price.groupby(by='price_date').mean()
active_monthly_price
# Out:
#             av_price
# price_date
# 2015-01-01  8.341565
# 2015-02-01  8.339562
# 2015-03-01  8.333455
# 2015-04-01  8.338910
# 2015-05-01  8.332926
# 2015-06-01  8.300007
# 2015-07-01  8.345481
# 2015-08-01  8.349604
# 2015-09-01  8.334521
# 2015-10-01  8.335168
# 2015-11-01  8.358883
# 2015-12-01  8.370689

# %%
"""
STEP 5: CALCULATING PERCENTAGE CHANGE IN PRICE
"""
# Churn percent change over the year
churn_pct = churn_monthly_price.pct_change()

churn_pct
# Out:
#             av_price
# price_date
# 2015-01-01       NaN
# 2015-02-01 -0.000736
# 2015-03-01  0.000880
# 2015-04-01 -0.001144
# 2015-05-01 -0.000839
# 2015-06-01 -0.006851
# 2015-07-01  0.008906
# 2015-08-01  0.001877
# 2015-09-01 -0.002431
# 2015-10-01 -0.001503
# 2015-11-01  0.000958
# 2015-12-01  0.003143

# %%
# Active customers percentage change in price
active_pct = active_monthly_price.pct_change()
active_pct
# Out:
#             av_price
# price_date
# 2015-01-01       NaN
# 2015-02-01 -0.000240
# 2015-03-01 -0.000732
# 2015-04-01  0.000655
# 2015-05-01 -0.000718
# 2015-06-01 -0.003950
# 2015-07-01  0.005479
# 2015-08-01  0.000494
# 2015-09-01 -0.001806
# 2015-10-01  0.000078
# 2015-11-01  0.002845
# 2015-12-01  0.001412

# %%
# plotting the relationship between the churn and active customer.
# This is to compare the distance between the two dataset on monthly price.
plt.plot(active_monthly_price, label='Active Customer', color='green')
plt.plot(churn_monthly_price, label='Churn Customer', color='steelblue')

plt.legend(title="CUSTOMER SEGMENT")

#adding axes labels and title
plt.ylabel('Monthly Price', fontsize=14)
plt.xlabel('Price_Date', fontsize=14)
plt.title('Churn and Active Customer Monthly Price', fontsize=16)

#display plot
plt.show()

# %% [markdown]
# Observation: From the graph above we can observe that there seem to be a huge different between the price of customers that have churn and active customer. and from this we can make a deduction that customer are sensitive to change in price but to make a 100% conclution, we can calculate divide the percenta
